# %%
import json
from pathlib import Path
from pprint import pprint

# %%
doe_to_deer = {
  "SecondarySchool": "ESe",
  "PrimarySchool": "Epr",
  "SmallOffice": "OfS",
  "MediumOffice": "OfL",
  "LargeOffice": "OfL",
  "SmallHotel": "Mtl",
  "LargeHotel": "Htl",
  "Warehouse": "SUn",
  "RetailStandalone": "RtL",
  "RetailStripmall": "RtS",
  "QuickServiceRestaurant": "RFF",
  "FullServiceRestaurant": "RSD",
  "MidriseApartment": "MFm",
  "HighriseApartment": "OfL",
  "Hospital": "Hsp",
  "Outpatient": "OfL",
  "SuperMarket": "Gro"
}

# %%
with open(Path("building_and_system_types.json"), 'r') as file:
    building_and_systems_types = json.load(file)
    
building_and_systems_types
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/2n/d6r18zp13z33v69kcdybq2_8_nmv05/T/ipykernel_36113/321373117.py in <module>
#       1 with open(Path("building_and_system_types.json"), 'r') as file:
# ----> 2     building_and_systems_types = json.load(file)
#       3
#       4 building_and_systems_types
#
# ~/.pyenv/versions/3.10.0/lib/python3.10/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~/.pyenv/versions/3.10.0/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/.pyenv/versions/3.10.0/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/.pyenv/versions/3.10.0/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
for k, v in building_and_systems_types.items():
    for occ_type in v:
        occ_type["standards_building_type"] = {
            "ASHRAE90_1": occ_type["standards_building_type"],
            "CA_TITLE24": doe_to_deer[occ_type["standards_building_type"]]
        }

# %%
building_and_systems_types
